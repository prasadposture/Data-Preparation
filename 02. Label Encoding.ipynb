# %% [markdown]
# # Label Encoding
# This process is used for converting categorical data into numeric data and is necessary step while preparing the data to feed the machines (computer program) since the machine do not understand any other language than the language of numbers. Label encoding helps us train our model in better manner since the categorical features would be dropped otherwise.

# %%
#Importing libraries
import pandas as pd
import numpy as np

# %%
#Loading the data
df=pd.read_csv('bank.csv',";")
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
#Getting the unique values for encoding
df['marital'].unique()
# Out:
# array(['married', 'single', 'divorced'], dtype=object)

# %%
#Label Encoding
df['marital']=df['marital'].map({'single':0, 'married':1,'divorced':2})
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed        1    primary      no     1787      no   no
# 1   33     services        1  secondary      no     4789     yes  yes
# 2   35   management        0   tertiary      no     1350     yes   no
# 3   30   management        1   tertiary      no     1476     yes  yes
# 4   59  blue-collar        1  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %% [markdown]
# It is easy to encode this way when the unique values of the particular column are less, but what if there are lot of them.

# %%
#Getting the unique values for encoding
df['job'].unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
df['job'].replace(
    {'unknown':np.nan, 
     'services':0,
     'management':1,
     'blue-collar':2,
     'self-employed':3,
     'technician':4,
     'entrepreneur':5,
     'admin.':6,
     'student':7,
     'housemaid':8,
     'retired':9,
     'unemployed':10 },
    inplace=True)
df.head()
# Out:
#    age   job  marital  education default  balance housing loan   contact  day  \
# 0   30  10.0        1    primary      no     1787      no   no  cellular   19
# 1   33   0.0        1  secondary      no     4789     yes  yes  cellular   11
# 2   35   1.0        0   tertiary      no     1350     yes   no  cellular   16
# 3   30   1.0        1   tertiary      no     1476     yes  yes   unknown    3
# 4   59   2.0        1  secondary      no        0     yes   no   unknown    5
#
#   month  duration  campaign  pdays  previous poutcome   y
# 0   oct        79         1     -1         0  unknown  no
# 1   may       220         1    339         4  failure  no
# 2   apr       185         1    330         1  failure  no
# 3   jun       199         4     -1         0  unknown  no
# 4   may       226         1     -1         0  unknown  no

# %% [markdown]
# In case when you have more unique values you can still encode them using the same method but this becomes time consuming process. In such cases we can use a function offered by `Sklearn` known as `LabelEncoder` for encoding our data.

# %% [markdown]
# #### Encoding with Label Encoder

# %%
#Importing function from the library
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %% [markdown]
# Let's replace all the months with numbers.

# %%
df['month'].unique()
#Month doesn't have `unknown` values
# Out:
# array(['oct', 'may', 'apr', 'jun', 'feb', 'aug', 'jan', 'jul', 'nov',
#        'sep', 'mar', 'dec'], dtype=object)

# %%
df["month"]=le.fit_transform(df["month"])
df.head()
# Out:
#    age   job  marital  education default  balance housing loan   contact  day  \
# 0   30  10.0        1    primary      no     1787      no   no  cellular   19
# 1   33   0.0        1  secondary      no     4789     yes  yes  cellular   11
# 2   35   1.0        0   tertiary      no     1350     yes   no  cellular   16
# 3   30   1.0        1   tertiary      no     1476     yes  yes   unknown    3
# 4   59   2.0        1  secondary      no        0     yes   no   unknown    5
#
#    month  duration  campaign  pdays  previous poutcome   y
# 0     10        79         1     -1         0  unknown  no
# 1      8       220         1    339         4  failure  no
# 2      0       185         1    330         1  failure  no
# 3      6       199         4     -1         0  unknown  no
# 4      8       226         1     -1         0  unknown  no

# %%
#df["contact"]=le.fit_transform(df["contact"])
#df.head()
#Doing this will also replace the `unknown` i.e. the missing value with some number
#We should take care of that using if-else block

# %%
#Replacing `unknown` with np.nan wiz missing values
for column in df.columns:
    df[column].replace({'unknown':np.nan}, inplace=True)
df.head()
# Out:
#    age   job  marital  education default  balance housing loan   contact  day  \
# 0   30  10.0        1    primary      no     1787      no   no  cellular   19
# 1   33   0.0        1  secondary      no     4789     yes  yes  cellular   11
# 2   35   1.0        0   tertiary      no     1350     yes   no  cellular   16
# 3   30   1.0        1   tertiary      no     1476     yes  yes       NaN    3
# 4   59   2.0        1  secondary      no        0     yes   no       NaN    5
#
#    month  duration  campaign  pdays  previous poutcome   y
# 0     10        79         1     -1         0      NaN  no
# 1      8       220         1    339         4  failure  no
# 2      0       185         1    330         1  failure  no
# 3      6       199         4     -1         0      NaN  no
# 4      8       226         1     -1         0      NaN  no

# %%
df['poutcome'].unique()
# Out:
# array([nan, 'failure', 'other', 'success'], dtype=object)

# %%
df['poutcome']=le.fit_transform(df['poutcome'])
df.head()
# Out:
#    age   job  marital  education default  balance housing loan   contact  day  \
# 0   30  10.0        1    primary      no     1787      no   no  cellular   19
# 1   33   0.0        1  secondary      no     4789     yes  yes  cellular   11
# 2   35   1.0        0   tertiary      no     1350     yes   no  cellular   16
# 3   30   1.0        1   tertiary      no     1476     yes  yes       NaN    3
# 4   59   2.0        1  secondary      no        0     yes   no       NaN    5
#
#    month  duration  campaign  pdays  previous  poutcome   y
# 0     10        79         1     -1         0         3  no
# 1      8       220         1    339         4         0  no
# 2      0       185         1    330         1         0  no
# 3      6       199         4     -1         0         3  no
# 4      8       226         1     -1         0         3  no

# %%
df['poutcome'].unique()
# Out:
# array([3, 0, 1, 2])

# %%
df['contact'].unique()
# Out:
# array(['cellular', nan, 'telephone'], dtype=object)

# %%
df['contact']=le.fit_transform(df['contact'])
df.head()
# Out:
#    age   job  marital  education default  balance housing loan  contact  day  \
# 0   30  10.0        1    primary      no     1787      no   no        0   19
# 1   33   0.0        1  secondary      no     4789     yes  yes        0   11
# 2   35   1.0        0   tertiary      no     1350     yes   no        0   16
# 3   30   1.0        1   tertiary      no     1476     yes  yes        2    3
# 4   59   2.0        1  secondary      no        0     yes   no        2    5
#
#    month  duration  campaign  pdays  previous  poutcome   y
# 0     10        79         1     -1         0         3  no
# 1      8       220         1    339         4         0  no
# 2      0       185         1    330         1         0  no
# 3      6       199         4     -1         0         3  no
# 4      8       226         1     -1         0         3  no

# %%
df['contact'].unique()
# Out:
# array([0, 2, 1])

# %% [markdown]
# You can see that it encodes the null values with highest digit, we will use this fact to replace the null value again with `np.nan`,

# %%
#Loading the data again while null values are replaced with np.nan
df=pd.read_csv('bank.csv',';')
for column in df.columns:
    df[column].replace({'unknown':np.nan}, inplace=True)
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0      NaN  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3       NaN    3   jun       199         4     -1         0      NaN  no
# 4       NaN    5   may       226         1     -1         0      NaN  no

# %%
#categorical columns
categorical_columns=['job','marital','education','default','housing','loan','contact','month','poutcome','y']

# %%
#categorical columns with null values
null_cat_cols=[]
for col in categorical_columns:
    if np.nan in list(df[col].unique()):
        null_cat_cols.append(col)
null_cat_cols
# Out:
# ['job', 'education', 'contact', 'poutcome']

# %%
#we will encode this using label encoder
for column in categorical_columns:
    df[column]=le.fit_transform(df[column])
df.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   30   10        1          0        0     1787        0     0        0
# 1   33    7        1          1        0     4789        1     1        0
# 2   35    4        2          2        0     1350        1     0        0
# 3   30    4        1          2        0     1476        1     1        2
# 4   59    1        1          1        0        0        1     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0   19     10        79         1     -1         0         3  0
# 1   11      8       220         1    339         4         0  0
# 2   16      0       185         1    330         1         0  0
# 3    3      6       199         4     -1         0         3  0
# 4    5      8       226         1     -1         0         3  0

# %% [markdown]
# While using the fact that null values are replaced at the end therefore having the highest numeric value in the respective column.

# %%
for col in null_cat_cols:
    df[col].replace({max(df[col]):np.nan}, inplace=True)
df.head()
#tadaa we got our missing values back
# Out:
#    age   job  marital  education  default  balance  housing  loan  contact  \
# 0   30  10.0        1        0.0        0     1787        0     0      0.0
# 1   33   7.0        1        1.0        0     4789        1     1      0.0
# 2   35   4.0        2        2.0        0     1350        1     0      0.0
# 3   30   4.0        1        2.0        0     1476        1     1      NaN
# 4   59   1.0        1        1.0        0        0        1     0      NaN
#
#    day  month  duration  campaign  pdays  previous  poutcome  y
# 0   19     10        79         1     -1         0       NaN  0
# 1   11      8       220         1    339         4       0.0  0
# 2   16      0       185         1    330         1       0.0  0
# 3    3      6       199         4     -1         0       NaN  0
# 4    5      8       226         1     -1         0       NaN  0

# %% [markdown]
# **Note** : It is always better to fill the missing values prior to the label encoding which saves lots of trouble and efforts.

# %%
#Saving the data for next session
df.to_csv('bank_encoded.csv',index=False)

# %% [markdown]
# The End
